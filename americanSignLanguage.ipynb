# %% [markdown]
# <a href="https://colab.research.google.com/github/Danvillah/Hospital/blob/main/americanSignLanguage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# AMERICAN SIGN LANGUAGE TRANSLATOR

# %%
import torch; print(torch.cuda.is_available())
# Out:
# False
